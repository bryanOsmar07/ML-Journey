# %% [markdown]
# # **Analisis de Negocio**
# ---

# %% [markdown]
# **"La mitad del dinero que gasto en publicidad se desperdicia; el problema es que no sé qué mitad".**
#
# > John Wanamaker, pionero del marketing a fines de la década de 1990 y principios del siglo XX, tiene fama de haber hecho esta declaración y los anunciantes han estado luchando con el problema desde entonces. <br>

# %% [markdown]
# Años atrás a muchas compañías les resultaba difícil cuantificar el impacto de varios canales de publicidad, como periódicos, televisión, radio, etc., en sus productos. Si bien estas compañías adoptaron ciertos métodos como solución al problema, esos métodos consistieron más en enfoques ingenuos que en técnicas sofisticadas y confiables.
#
# A fines de la década de 1990, las cosas comenzaron a cambiar y el arte de las mediciones de marketing se hizo más maduro debido a la influencia de los grupos econométricos con agencias de publicidad que encontraron mejores formas de obtener información de la compleja gama de mediciones de marketing que se conoció como Marketing Mix Modeling.

# %% [markdown]
# **¿Qué es Marketing Mix Modelling?**

# %% [markdown]
# El Marketing Mix Modeling abarca el método de análisis estadístico, como la regresión en las ventas y los datos de marketing para estimar el impacto de varias tácticas de marketing en las ventas y luego predecir el impacto de futuros conjuntos de tácticas. También se utiliza para optimizar la combinación de publicidad y las tácticas promocionales con respecto a los ingresos por ventas o ganancias. Hoy, la mayoría de las marcas y empresas han adoptado y están adoptando estas metodologías de medición avanzadas para determinar el verdadero impacto de todas las interacciones en todos los dispositivos, canales y tácticas de campaña.
#
# Hoy en día, la mayoría de las empresas tienen una base sólida de modelos econométricos con estrategias ligeramente diferentes según sus requisitos, productos, competencia externa, etc.

# %% [markdown]
# **Entendiendo cada palabra de "Marketing Mix Modelling"**

# %% [markdown]
# > Al romper la frase, obtenemos tres palabras, es decir, marketing, mezcla y modelado. Exploremos estos términos.
# 1. Marketing: este término corresponde a la comprensión del mercado.
# 2. Mezclar: Mezclar aquí se refiere a la importancia que se le debe dar a cada P en el 4 P (Producto, precio, lugar y promoción)
# 3. Modelado: el modelado aquí se refiere a la optimización y construcción del modelo.

# %% [markdown]
# **Diseño de la combinación de marketing correcta:**

# %% [markdown]
# El paso más creativo y desafiante en el marketing es diseñar la combinación de marketing adecuada. La combinación de marketing es una colección específica de acciones e instrumentos asociados empleados por una organización para estimular la aceptación de sus ideas, productos y servicios.

# %% [markdown]
# **Oferta final al cliente:**

# %% [markdown]
# La oferta final hecha al cliente o consumidor depende del gerente de marketing de la empresa.
# donde se siguen los siguientes cuatro pasos.
# 1. La empresa (o el gerente de marketing elige el producto para satisfacer las demandas del mercado).
# 2. El canal de distribución correcto se utiliza para hacer que el producto esté disponible.
# 3. Se ofrece al cliente una promoción llamativa para los productos.
# 4. Además de la promoción, se fija el precio apropiado acordado por la empresa y el cliente.

# %% [markdown]
# **Nota:**
# 1. Sin embargo, el término 'marketing mix' no implica que los elementos 4P representen opciones.
# 2. No son compensaciones, pero son cuestiones fundamentales de marketing que siempre deben abordarse.
# 3. Son las acciones fundamentales que requiere el marketing, ya sea determinado explícitamente o por defecto.

# %% [markdown]
# **Optimizando la mezcla de marketing:**
# > Al ofrecer el producto con una combinación de 4 P, la popularidad del producto y los ingresos por ventas de la empresa que vende ese producto aumentarán gradualmente.
# Hay 2 optimizaciones que se pueden implementar.
# 1. Optimización estratégica:
#    > Esto aparece cuando se realizan grandes cambios en el peso dado a una P particular o un grupo de P's. Por ejemplo, un gran cambio en el precio de S/.500 a S/.1000 podría tener un profundo efecto en los ingresos por ventas. Este tipo de cambios cae en esta categoría.
# 2. Optimización táctica:
#    > Esto aparece cuando se hacen pequeños cambios en el peso dado a una P particular o un grupo de P's. Por ejemplo, considerando el ejemplo anterior para la Optimización estratégica, si el Precio cambia de S/.500 a S/.499, entonces este tipo de cambios se encuadra en la Optimización táctica.

# %% [markdown]
# **Fortalezas y debilidades de MMM:**

# %% [markdown]
# **Fortalezas:**
# > Un modelo de marketing mix implementado con éxito puede proporcionar los siguientes beneficios:
#   1. Reflexiona sobre las decisiones de marketing tomadas en el pasado, calculando el retorno de la inversión (ROI).
#   2. Ayuda a optimizar el mix de marketing para las empresas al pronosticar el impacto probable de los cambios en varias variables del mix de marketing.
#   3. Ayuda a encontrar los cambios en el desempeño del negocio al aislar el impacto de factores internos y externos.

# %% [markdown]
# **Debilidad:**
# >
# 1. El enfoque en las ventas a corto plazo puede subestimar significativamente la importancia de las actividades de creación de capital a largo plazo
# 2. MMM, utilizado para la optimización de la mezcla de medios, tiene un sesgo a favor de los medios dependientes del tiempo (como la televisión) frente a los medios menos dependientes del tiempo (como los anuncios que aparecen en revistas mensuales); Los sesgos también pueden ocurrir cuando se comparan medios de amplia base versus medios demográficamente dirigidos.

# %% [markdown]
#  **Trabajando un MMM**

# %% [markdown]
# Comprendamos el funcionamiento de MMM con un ejemplo.
# Básicamente, los MMM se analizan e implementan con algoritmos de aprendizaje estadísticos como la regresión.
#
# Se utilizan muchos tipos de regresión en MMM para una mejor precisión y rendimiento. Algunos de ellos son regresión lineal, regresión multivariada, etc.

# %% [markdown]
# **Conexion Drive**

# %%
# Si necesitas ejecutar el notebook con un archivo desde tu drive personal
# from google.colab import drive
# drive.mount('/gdrive')

# Repositorios
# path = '/gdrive/MyDrive/BQ - Data Science/BQ - Repositorios/Repositorio_Portafolio/'
# filename = "Data_Marketing_Mix_Modelling.csv"
# fullpath = os.path.join(path, filename)

# %% [markdown]
# ### **Librerias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# Para los graficos tengan las mismas dimensiones
# %matplotlib inline
plt.style.use('ggplot')
#plt.rcParams['figure.figsize'] = (7, 4)

pd.options.display.max_columns = None
sns.set_style('whitegrid')
color = sns.color_palette()

# %% [markdown]
# ## Rutas

# %%
fullpath = 'https://raw.githubusercontent.com/bryanOsmar07/personal-projects-portafolio/main/Data/Data_Marketing_Mix_Modelling.csv'

# %% [markdown]
# # **Lectura de datos**

# %%
df = pd.read_csv(fullpath)

# %%
print(df.shape)
df.head(3)
# Out:
# (200, 7)
#    Unnamed: 0.1  Unnamed: 0 Periodo     TV  radio  newspaper  sales
# 0             0           1  Ene-13  230.1   37.8       69.2  22100
# 1             1           2  Feb-13   44.5   39.3       45.1  10400
# 2             2           3  Mar-13   17.2   45.9       69.3   9300

# %% [markdown]
# # **Data Wrangling**

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Periodo', 'TV', 'radio', 'newspaper',
#        'sales'],
#       dtype='object')

# %%
# Validamos si los tipos de variables son los adecuados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  200 non-null    int64
#  1   Unnamed: 0    200 non-null    int64
#  2   Periodo       200 non-null    object
#  3   TV            200 non-null    float64
#  4   radio         200 non-null    float64
#  5   newspaper     200 non-null    float64
#  6   sales         200 non-null    int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 11.1+ KB

# %%
# Eliminamos la primera columna
df = df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1)

# %%
target = 'sales'
columnsNumeric = ['radio', 'newspaper','TV']

# %% [markdown]
# # **I. Analisis Exploratorio**

# %%
df.describe(include='all').T
# Out:
#            count unique     top freq      mean          std     min      25%  \
# Periodo      200    200  Ene-13    1       NaN          NaN     NaN      NaN
# TV         200.0    NaN     NaN  NaN  147.0425    85.854236     0.7   74.375
# radio      200.0    NaN     NaN  NaN    23.264    14.846809     0.0    9.975
# newspaper  200.0    NaN     NaN  NaN    30.554    21.778621     0.3    12.75
# sales      200.0    NaN     NaN  NaN   14022.5  5217.456566  1600.0  10375.0
#
#                50%      75%      max
# Periodo        NaN      NaN      NaN
# TV          149.75  218.825    296.4
# radio         22.9   36.525     49.6
# newspaper    25.75     45.1    114.0
# sales      12900.0  17400.0  27000.0

# %% [markdown]
# ## Revision Objetivo

# %%
plt.figure(figsize=(12,3))
sns.histplot(x=target, data=df);

# %%
fig = plt.figure(figsize=(8,4))
fig.add_subplot(2,1,1)
sns.distplot(df[target])
fig.add_subplot(2,1,2)
sns.boxplot(df[target])
plt.tight_layout()

# %%
import plotly.express as px

# %%
fig1 = px.line(df, x=df.Periodo, y=target,template = "plotly_white",title='ss')
fig1.update_layout(width=1000, height=300)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b8c54e30-8c56-47f6-bfec-d243cc803b56" class="plotly-graph-div" style="height:300px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8c54e30-8c56-47f6-bfec-d243cc803b56")) {                    Plotly.newPlot(                        "b8c54e30-8c56-47f6-bfec-d243cc803b56",                        [{"hovertemplate":"Periodo=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Ene-13","Feb-13","Mar-13","Abr-13","May-13","Jun-13","Jul-13","Ago-13","Set-13","Oct-13","Nov-13","Dic-13","Ene-14","Feb-14","Mar-14","Abr-14","May-14","Jun-14","Jul-14","Ago-14","Set-14","Oct-14","Nov-14","Dic-14","Ene-15","Feb-15","Mar-15","Abr-15","May-15","Jun-15","Jul-15","Ago-15","Set-15","Oct-15","Nov-15","Dic-15","Ene-16","Feb-16","Mar-16","Abr-16","May-16","Jun-16","Jul-16","Ago-16","Set-16","Oct-16","Nov-16","Dic-16","Ene-17","Feb-17","Mar-17","Abr-17","May-17","Jun-17","Jul-17","Ago-17","Set-17","Oct-17","Nov-17","Dic-17","Ene-18","Feb-18","Mar-18","Abr-18","May-18","Jun-18","Jul-18","Ago-18","Set-18","Oct-18","Nov-18","Dic-18","Ene-19","Feb-19","Mar-19","Abr-19","May-19","Jun-19","Jul-19","Ago-19","Set-19","Oct-19","Nov-19","Dic-19","Ene-20","Feb-20","Mar-20","Abr-20","May-20","Jun-20","Jul-20","Ago-20","Set-20","Oct-20","Nov-20","Dic-20","Ene-21","Feb-21","Mar-21","Abr-21","May-21","Jun-21","Jul-21","Ago-21","Set-21","Oct-21","Nov-21","Dic-21","Ene-22","Feb-22","Mar-22","Abr-22","May-22","Jun-22","Jul-22","Ago-22","Set-22","Oct-22","Nov-22","Dic-22","Ene-23","Feb-23","Mar-23","Abr-23","May-23","Jun-23","Jul-23","Ago-23","Set-23","Oct-23","Nov-23","Dic-23","Ene-24","Feb-24","Mar-24","Abr-24","May-24","Jun-24","Jul-24","Ago-24","Set-24","Oct-24","Nov-24","Dic-24","Ene-25","Feb-25","Mar-25","Abr-25","May-25","Jun-25","Jul-25","Ago-25","Set-25","Oct-25","Nov-25","Dic-25","Ene-26","Feb-26","Mar-26","Abr-26","May-26","Jun-26","Jul-26","Ago-26","Set-26","Oct-26","Nov-26","Dic-26","Ene-27","Feb-27","Mar-27","Abr-27","May-27","Jun-27","Jul-27","Ago-27","Set-27","Oct-27","Nov-27","Dic-27","Ene-28","Feb-28","Mar-28","Abr-28","May-28","Jun-28","Jul-28","Ago-28","Set-28","Oct-28","Nov-28","Dic-28","Ene-29","Feb-29","Mar-29","Abr-29","May-29","Jun-29","Jul-29","Ago-29"],"xaxis":"x","y":[22100,10400,9300,18500,12900,7200,11800,13200,4800,10600,8600,17400,9200,9700,19000,22400,12500,24400,11300,14600,18000,12500,5600,15500,9700,12000,15000,15900,18900,10500,21400,11900,9600,17400,9500,12800,25400,14700,10100,21500,16600,17100,20700,12900,8500,14900,10600,23200,14800,9700,11400,10700,22600,21200,20200,23700,5500,13200,23800,18400,8100,24200,15700,14000,18000,9300,9500,13400,18900,22300,18300,12400,8800,11000,17000,8700,6900,14200,5300,11000,11800,12300,11300,13600,21700,15200,12000,16000,12900,16700,11200,7300,19400,22200,11500,16900,11700,15500,25400,17200,11700,23800,14800,14700,20700,19200,7200,8700,5300,19800,13400,21800,14100,15900,14600,12600,12200,9400,15900,6600,15500,7000,11600,15200,19700,10600,6600,8800,24700,9700,1600,12700,5700,19600,10800,11600,9500,20800,9600,20700,10900,19200,20100,10400,11400,10300,13200,25400,10900,10100,16100,11600,16600,19000,15600,3200,15300,10100,7300,12900,14400,13300,14900,18000,11900,11900,8000,12200,17100,15000,8400,14500,7600,11700,11500,27000,20200,11700,11800,12600,10500,12200,8700,26200,17600,22600,10300,17300,15900,6700,10800,9900,5900,19600,17300,7600,9700,12800,25500,13400],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpol ...

# %% [markdown]
# ## Analisis Univariado

# %% [markdown]
# ### Numericas

# %%
df[columnsNumeric].describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4

# %%
df.groupby(target).median() # Mediana no se ve afectada con valores atípicos
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     496
# --> 497         return self._call_cython_op(
#     498             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540         out_shape = self._get_output_shape(ngroups, values)
# --> 541         func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542         values = self._get_cython_vals(values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     166                 # no fused types -> no __signatures__
# --> 167                 raise NotImplementedError(
#     168                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->median,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     785         try:
# --> 786             values = values.astype("f8")
#     787         except ValueError as err:
#
# ValueError: could not convert string to float: 'Nov-23'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-fdc0db8f83af> in <cell line: 1>()
# ----> 1 df.groupby(target).median() # Mediana no se ve afectada con valores atípicos
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in median(self, numeric_only)
#    1881             Median of values within each group.
#    1882         """
# -> 1883         result = self._cython_agg_general(
#    1884             "median",
#    1885             alt=lambda x: Series(x).median(numeric_only=numeric_only),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1505             return result
#    1506
# -> 1507         new_mgr = data.grouped_reduce(array_func)
#    1508         res = self._wrap_agged_manager(new_mgr)
#    1509         out = self._wrap_aggregated_output(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1501                 #  while others do not.
#    1502                 for sb in blk._split():
# -> 1503                     applied = sb.apply(func)
#    1504                     result_blocks = extend_blocks(applied, result_blocks)
#    1505             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     327         one
#     328         """
# --> 329         result = func(self.values, **kwargs)
#     330
#     331         return self._split_op_result(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1501                 # try to python agg
#    1502                 # TODO: shouldn't min_count matter?
# -> 1503                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1504
#    1505             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1455         #  should always be preserved by the implemented aggregations
#    1456         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1458
#    1459         if isinstance(values, Categorical):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     992             preserve_dtype = True
#     993
# --> 994         result = self._aggregate_series_pure_python(obj, func)
#     995
#     996         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#    1013
#    1014         for i, group in enumerate(splitter):
# -> 1015             res = func(group)
#    1016             res = libreduction.extract_result(res)
#    1017
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1883         result = self._cython_agg_general(
#    1884             "median",
# -> 1885             alt=lambda x: Series(x).median(numeric_only=numeric_only),
#    1886             numeric_only=numeric_only,
#    1887         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11621             **kwargs,
#   11622         ):
# > 11623             return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11624
#   11625         setattr(cls, "median", median)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11210         **kwargs,
#   11211     ) -> Series | float:
# > 11212         return self._stat_function(
#   11213             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11214         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11157
# > 11158         return self._reduce(
#   11159             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4668                 )
#    4669             with np.errstate(all="ignore"):
# -> 4670                 return op(delegate, skipna=skipna, **kwds)
#    4671
#    4672     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     156                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157             else:
# --> 158                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     159
#     160             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     787         except ValueError as err:
#     788             # e.g. "could not convert string to float: 'a'"
# --> 789             raise TypeError(str(err)) from err
#     790     if mask is not None:
#     791         values[mask] = np.nan
#
# TypeError: could not convert string to float: 'Nov-23'

# %%
for x in columnsNumeric:
  plt.figure(figsize=(15,4), dpi=80)
  plt.title(df[x].name)
  plt.hist(df[x],bins=100)
  plt.show()

# %%
# No consideramos las colas (outliers) para ver mejor la distribucion
for x in columnsNumeric:
  plt.figure(figsize=(15,4), dpi=80)
  Q03= int(df[x].quantile(0.75))+100
  plt.title(df[x].name)
  plt.hist(df[x],bins=100,range=(0,Q03))
  plt.show()

# %%
df.hist(bins=100,figsize=(20,10));

# %%
num_bins = 10
data_0 = df

for i in columnsNumeric:
    n, bins, patches = plt.hist(data_0[i], num_bins, facecolor='blue', alpha=0.5)
    plt.xlabel(i)
    plt.ylabel('Número')
    plt.show()

# %%
# Grafico de Cajas para revision de atipicos
for x in columnsNumeric:
  plt.figure(figsize=(15,4), dpi=80)
  plt.title(df[x].name)
  sns.boxplot(x=df[x], palette="Blues")
  plt.show()

# %% [markdown]
# ## Analisis Multivariado

# %%
df
# Out:
#     Periodo     TV  radio  newspaper  sales
# 0    Ene-13  230.1   37.8       69.2  22100
# 1    Feb-13   44.5   39.3       45.1  10400
# 2    Mar-13   17.2   45.9       69.3   9300
# 3    Abr-13  151.5   41.3       58.5  18500
# 4    May-13  180.8   10.8       58.4  12900
# ..      ...    ...    ...        ...    ...
# 195  Abr-29   38.2    3.7       13.8   7600
# 196  May-29   94.2    4.9        8.1   9700
# 197  Jun-29  177.0    9.3        6.4  12800
# 198  Jul-29  283.6   42.0       66.2  25500
# 199  Ago-29  232.1    8.6        8.7  13400
#
# [200 rows x 5 columns]

# %%
# Analizamos la correlacion de las variables
# Spearman: Para variables numericas. No asume normalidad
plt.figure(figsize=(11,5), dpi=80)
sns.heatmap(abs(df[columnsNumeric].corr(method='spearman')),annot=True,fmt='.1f',cmap='Blues')
plt.show()

# %% [markdown]
# Inmediatamente, podemos ver que hay una fuerte correlación entre TV y ventas (0.78), una correlación moderada entre radio y ventas (0.58), y una correlación débil entre periódico y ventas (0.23). Todavía es demasiado pronto para concluir algo, pero es bueno tenerlo en cuenta para seguir adelante.
# De manera similar a la matriz de correlación, quiero crear un diagrama de pares de mis variables para poder comprender aún más las relaciones entre mis variables.

# %%
sns.pairplot(df[columnsNumeric])

# %% [markdown]
# Esto parece estar en línea con la matriz de correlación, ya que parece haber una fuerte relación entre la televisión y las ventas, menos para la radio y aún menos para los periódicos.

# %% [markdown]
# ## Linealidad

# %%
# Linealidad
p = sns.pairplot(df, x_vars = columnsNumeric,
                 y_vars=target, size=3, aspect=0.7)

# %%
# Multicolinealidad
corr = df[columnsNumeric].corr()
mask = np.zeros_like(corr, dtype=np.bool_)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(15, 4))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %% [markdown]
# ### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(df[columnsNumeric].values, i) for i in range(df[columnsNumeric].shape[1])]
vif["features"] = df[columnsNumeric].columns
vif
# Out:
#    VIF Factor   features
# 0    3.285462      radio
# 1    3.055245  newspaper
# 2    2.486772         TV

# %% [markdown]
# ## Asimetria

# %% [markdown]
# Calculamos el Coeficiente de Asimetría

# %%
from scipy import stats

# %%
data_ca = {'Variable' : columnsNumeric,
       'Coeficiente_Asim' : stats.skew(df[columnsNumeric])}
asim = pd.DataFrame(data_ca)
asim
# Out:
#     Variable  Coeficiente_Asim
# 0      radio          0.093467
# 1  newspaper          0.887996
# 2         TV         -0.069328

# %% [markdown]
# ## Tratamiento de Nulos

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Periodo      0
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Periodo      0.0
# TV           0.0
# radio        0.0
# newspaper    0.0
# sales        0.0
# dtype: float64

# %% [markdown]
# ## **Importancia de las variables**
#
# La importancia de la característica le permite determinar cuán "importante" es cada variable de entrada para predecir la variable de salida. Una característica es importante si mezclar sus valores aumenta el error del modelo porque esto significa que el modelo se basó en la característica para la predicción.
# Vamos a crear rápidamente un modelo de bosque aleatorio para que podamos determinar la importancia de cada característica.

# %%
# Building Random Forest model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae

# %%
df.head(2)
# Out:
#   Periodo     TV  radio  newspaper  sales
# 0  Ene-13  230.1   37.8       69.2  22100
# 1  Feb-13   44.5   39.3       45.1  10400

# %%
# Setting X and y variables
X = df[columnsNumeric]
y = df['sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=0)
model = RandomForestRegressor(random_state=1)
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
# Visualizing Feature Importance
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(25).plot(kind='barh',figsize=(15,4))
# Out:
# <Axes: >

# %% [markdown]
# # **Modelado**

# %%
df.head(3)
# Out:
#   Periodo     TV  radio  newspaper  sales
# 0  Ene-13  230.1   37.8       69.2  22100
# 1  Feb-13   44.5   39.3       45.1  10400
# 2  Mar-13   17.2   45.9       69.3   9300

# %% [markdown]
# ## **Regresión OLS**
#
# Parece haber un patrón, donde la televisión es lo más importante, seguida de la radio, dejando el periódico al final. Realmente construyamos nuestro modelo de regresión OLS.

# %%
import statsmodels.formula.api as sm

# %%
model = sm.ols(formula="sales~TV+radio+newspaper", data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 18 Jul 2024   Prob (F-statistic):           1.58e-96
# Time:                        00:18:56   Log-Likelihood:                -1767.7
# No. Observations:                 200   AIC:                             3543.
# Df Residuals:                     196   BIC:                             3557.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2938.8894    311.908      9.422      0.000    2323.762    3554.016
# TV            45.7646      1.395     32.809      0.000      43.014      48.516
# radio        188.5300      8.611     21.893      0.000     171.547     205.513
# newspaper     -1.0375      5.871     -0.177      0.860     -12.616      10.541
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# El R-cuadrado es 0.896, lo que significa que casi 90 de todas las variaciones en nuestros datos pueden explicarse por nuestro modelo, ¡lo cual es bastante bueno!
#
# Los valores p para TV y radio son inferiores a 0,000, pero el valor p para periódicos es 0,86, lo que indica que el gasto en periódicos no tiene un impacto significativo en las ventas (t = '0.177) y su pvalor es 0.86 (muy por encima del 0.05).
# A continuación, grafiquemos los valores de ventas pronosticados con los valores de ventas reales para ver visualmente cómo funciona nuestro modelo:

# %% [markdown]
# ### **Métricas**

# %%
# Defining Actual and Predicted values
y_pred = model.predict()
labels = df['sales']
df_temp = pd.DataFrame({'Actual': labels, 'Predicted':y_pred})
df_temp.head()
# Creating Line Graph
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
y1 = df_temp['Actual']
y2 = df_temp['Predicted']
plt.plot(y1, label = 'Actual')
plt.plot(y2, label = 'Predicted')
plt.legend()
plt.show()

# %% [markdown]
# En la práctica, es probable que desee considerar más variables que afecten las ventas, incluidas, entre otras, las siguientes:
#
# **Estacionalidad** : casi siempre ocurre que las ventas de la empresa son estacionales. Por ejemplo, las ventas de una compañía de snowboard serían mucho más altas durante el invierno que en el verano. En la práctica, querrás incluir una variable para tener en cuenta la estacionalidad.
#
# **Efectos de arrastre** : el impacto del marketing no suele ser inmediato. En muchos casos, los consumidores necesitan tiempo para pensar en sus decisiones de compra después de ver anuncios. Los efectos de transferencia representan el lapso de tiempo entre el momento en que los consumidores están expuestos a un anuncio y su respuesta al anuncio.
#
# **Ventas base vs ventas incrementales**: no todas las ventas se atribuyen al marketing. Si una empresa no gastara absolutamente nada en marketing y todavía hiciera ventas, esto se llamaría su base de ventas . Por lo tanto, para ir un paso más allá, podría intentar modelar el gasto publicitario en ventas incrementales en lugar de las ventas totales.
